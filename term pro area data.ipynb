# %%
NAMES = ["Andrew Fidler",
         "Ryan Da Silva",
         "Mike Suderman",
         "Pavel Demin",
         "Saewan Koh",
         ]
GROUP = "4"

# %%
import pandas as pd

# %%
# read data
by_area = pd.read_csv('term pro area data.csv')

# %%
# drop redundant columns
by_area = by_area[[
    'REF_DATE',
    'Population centre and rural areas',
    'VALUE',
]]

# %%
# pivot table to show collected values
by_area = by_area.pivot(index=["Population centre and rural areas"], 
            columns=["REF_DATE"],
            values="VALUE")

# %%
by_area.head()
# Out:
# REF_DATE                                            2011-01  2011-02  2011-03  \
# Population centre and rural areas
# Census metropolitan area and census agglomeration    4711.7   4686.6   4708.6
# Non-census metropolitan area and non-census agg...    475.0    486.9    472.9
#
# REF_DATE                                            2011-04  2011-05  2011-06  \
# Population centre and rural areas
# Census metropolitan area and census agglomeration    4774.8   4799.5   4865.6
# Non-census metropolitan area and non-census agg...    478.3    491.1    504.3
#
# REF_DATE                                            2011-07  2011-08  2011-09  \
# Population centre and rural areas
# Census metropolitan area and census agglomeration    4814.2   4842.0   4751.5
# Non-census metropolitan area and non-census agg...    490.1    477.2    477.9
#
# REF_DATE                                            2011-10  ...  2022-05  \
# Population centre and rural areas                            ...
# ...

# %%
# look at data percantagewise
by_area.apply(lambda x: round(100 * x / x.sum()))
# Out:
# REF_DATE                                            2011-01  2011-02  2011-03  \
# Population centre and rural areas
# Census metropolitan area and census agglomeration      91.0     91.0     91.0
# Non-census metropolitan area and non-census agg...      9.0      9.0      9.0
#
# REF_DATE                                            2011-04  2011-05  2011-06  \
# Population centre and rural areas
# Census metropolitan area and census agglomeration      91.0     91.0     91.0
# Non-census metropolitan area and non-census agg...      9.0      9.0      9.0
#
# REF_DATE                                            2011-07  2011-08  2011-09  \
# Population centre and rural areas
# Census metropolitan area and census agglomeration      91.0     91.0     91.0
# Non-census metropolitan area and non-census agg...      9.0      9.0      9.0
#
# REF_DATE                                            2011-10  ...  2022-05  \
# Population centre and rural areas                            ...
# ...
